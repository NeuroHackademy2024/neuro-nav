# %%
import pandas as pd


#read in tractometry csv from a single subject
sub = '930449'

fname = f's3://open-neurodata/rokem/hcp1200/afq/sub-{sub}/ses-01/sub-{sub}_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv'
#'https://{{bucket}}.s3.amazonaws.com/{{key}}'
bucket = 'open-neurodata'
key = f'rokem/hcp1200/afq/sub-{sub}/ses-01/sub-{sub}_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv'
fname2 = f'https://{bucket}.s3.amazonaws.com/{key}'

df = pd.read_csv(fname2, index_col = 0)

df.head()
# Out:
#   tractID  nodeID    dki_fa    dki_md    dki_mk   dki_awf
# 0   ATR_R       0  0.240520  0.000877  0.668971  0.236666
# 1   ATR_R       1  0.293841  0.000879  0.751055  0.259638
# 2   ATR_R       2  0.334611  0.000895  0.825566  0.282275
# 3   ATR_R       3  0.371301  0.000904  0.879683  0.302245
# 4   ATR_R       4  0.400966  0.000905  0.922666  0.319311

# %%
from utilities import ls
print(fname2)
# !wget https://open-neurodata.s3.amazonaws.com/rokem/hcp1200/afq/sub-930449/ses-01/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv -P /tmp/cache
df = pd.read_csv('/tmp/cache/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv.1', index_col = 0)
df.head()
# Out:
# https://open-neurodata.s3.amazonaws.com/rokem/hcp1200/afq/sub-930449/ses-01/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv
# --2024-08-07 16:43:21--  https://open-neurodata.s3.amazonaws.com/rokem/hcp1200/afq/sub-930449/ses-01/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv
# Resolving open-neurodata.s3.amazonaws.com (open-neurodata.s3.amazonaws.com)... 16.182.104.249, 3.5.25.201, 3.5.12.236, ...
# Connecting to open-neurodata.s3.amazonaws.com (open-neurodata.s3.amazonaws.com)|16.182.104.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 225327 (220K) [binary/octet-stream]
# Saving to: ‘/tmp/cache/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv.2’
#
# sub-930449_dwi_spac 100%[===================>] 220.05K  1.12MB/s    in 0.2s
#
# 2024-08-07 16:43:22 (1.12 MB/s) - ‘/tmp/cache/sub-930449_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv.2’ saved [225327/225327]
# ...

# %%
# !wget --help
# Out:
# GNU Wget 1.21.2, a non-interactive network retriever.
# Usage: wget [OPTION]... [URL]...
#
# Mandatory arguments to long options are mandatory for short options too.
#
# Startup:
#   -V,  --version                   display the version of Wget and exit
#   -h,  --help                      print this help
#   -b,  --background                go to background after startup
#   -e,  --execute=COMMAND           execute a `.wgetrc'-style command
#
# Logging and input file:
#   -o,  --output-file=FILE          log messages to FILE
#   -a,  --append-output=FILE        append messages to FILE
#   -d,  --debug                     print lots of debugging information
#   -q,  --quiet                     quiet (no output)
#   -v,  --verbose                   be verbose (this is the default)
#   -nv, --no-verbose                turn off verboseness, without being quiet
#        --report-speed=TYPE         output bandwidth as TYPE.  TYPE can be bits
# ...
